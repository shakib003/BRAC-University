# %%
input_file=open("/content/untitled","r")
n = input_file.readline()
A = []
a = []
B = {}

for i in range(int(n)):
  b = []
  u,v = input_file.readline().split()
  u = int(u)
  v = int(v)
  A.append([v,u])
  a.append(v)
  for j in range(u,v+1):
    b.append(j)
    B[len(A)-1] = b

A.sort()

for k in range(int(n)-1):
  temp = A[k]
  print("t",temp)
  for l in range(int(n)-1):
    if temp[0] and temp[1] in B[l]:
      del B[l]
      #temp.reverse()
      #print("1",temp)
    #else:
      #temp.reverse()
     #print(temp)
    print(temp)

  
#print(A)
#print(B)

#A.sort()
#print(A)
# Out:
# t [2, 1]
# [2, 1]
# [2, 1]
# [2, 1]
# [2, 1]
# [2, 1]
# [2, 1]
# t [3, 2]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-6d4da83e1a05> in <module>
#      22   print("t",temp)
#      23   for l in range(int(n)-1):
# ---> 24     if temp[0] and temp[1] in B[l]:
#      25       del B[l]
#      26       #temp.reverse()
#
# KeyError: 0
